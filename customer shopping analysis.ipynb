# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("G:\Computer Science\Ai_Data Science\My Projects\customer_shopping_behavior python & Sql & powerbi\customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isna().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df=df.rename(columns={"Purchase Amount (USD)":"Purchase Amount "})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df.review_rating=df.groupby("category")["review_rating"].transform(lambda x : x.fillna(x.median()))

# %%
df.isna().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchase_amount_          0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %%
min_age=df["age"].min()
max_age=df["age"].max()
print(min_age)
print(max_age)
# Out:
# 18
# 70

# %%
bins=[17,25,40,55,71]
label = ["Adult","Middle Age","Men","Senior"]
df["age_groub"]=pd.cut(df["age"],bins=bins,labels=label)

# %%
df[["age","age_groub"]]
# Out:
#       age   age_groub
# 0      55         Men
# 1      19       Adult
# 2      50         Men
# 3      21       Adult
# 4      45         Men
# ...   ...         ...
# 3895   40  Middle Age
# 3896   52         Men
# 3897   46         Men
# 3898   44         Men
# 3899   52         Men
#
# [3900 rows x 2 columns]

# %%
df.age_groub.value_counts()
# Out:
# age_groub
# Men           1121
# Senior        1105
# Middle Age    1103
# Adult          571
# Name: count, dtype: int64

# %%
df.age_groub.isna().sum()
# Out:
# 0

# %%
frequency = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}
df["frequency"]=df.frequency_of_purchases.map(frequency)

# %%
df[["frequency","frequency_of_purchases"]]
# Out:
#       frequency frequency_of_purchases
# 0            14            Fortnightly
# 1            14            Fortnightly
# 2             7                 Weekly
# 3             7                 Weekly
# 4           365               Annually
# ...         ...                    ...
# 3895          7                 Weekly
# 3896         14              Bi-Weekly
# 3897         90              Quarterly
# 3898          7                 Weekly
# 3899         90              Quarterly
#
# [3900 rows x 2 columns]

# %%
df[["discount_applied","promo_code_used"]]
# Out:
#      discount_applied promo_code_used
# 0                 Yes             Yes
# 1                 Yes             Yes
# 2                 Yes             Yes
# 3                 Yes             Yes
# 4                 Yes             Yes
# ...               ...             ...
# 3895               No              No
# 3896               No              No
# 3897               No              No
# 3898               No              No
# 3899               No              No
#
# [3900 rows x 2 columns]

# %%
(df["discount_applied"]==df["promo_code_used"]).all()
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
df.groupby("subscription_status")["purchase_amount_"].mean()
# Out:
# subscription_status
# No     59.865121
# Yes    59.491928
# Name: purchase_amount_, dtype: float64

# %%
df.groupby("subscription_status")["customer_id"].count()
# Out:
# subscription_status
# No     2847
# Yes    1053
# Name: customer_id, dtype: int64

# %%
df.groupby("gender")["purchase_amount_"].mean()
# Out:
# gender
# Female    60.249199
# Male      59.536199
# Name: purchase_amount_, dtype: float64

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mssql+pyodbc://DESKTOP-AH3MGU8/customer_behavior?"
    "driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes"
)

# %%
df.to_sql("customer_behavior",engine,if_exists="replace",index=False)
# Out:
# 52

# %%
pd.read_sql("select Top 5 * from customer_behavior",engine)
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_  \
# 0            1   55   Male         Blouse  Clothing                53
# 1            2   19   Male        Sweater  Clothing                64
# 2            3   50   Male          Jeans  Clothing                73
# 3            4   21   Male        Sandals  Footwear                90
# 4            5   45   Male         Blouse  Clothing                49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code_used  previous_purchases  \
# ...
